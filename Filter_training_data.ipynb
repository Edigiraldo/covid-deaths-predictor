# %%
import json
import os
import pandas as pd

# %%
confirmed_cases_processed_csv = '/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/confirmed_cases_processed.csv'
confirmed_deaths_processed_csv = '/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/confirmed_deaths_processed.csv'
fully_vaccinated_processed_csv = '/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/fully_vaccinated_processed.csv'
partially_vaccinated_processed_csv = '/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/partially_vaccinated_processed.csv'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
os.listdir('/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data')
# Out:
# ['max_covid_confirmed_by_country.csv',
#  'confirmed_cases_processed.csv',
#  'confirmed_deaths_processed.csv',
#  'partially_vaccinated_processed.csv',
#  'fully_vaccinated_processed.csv',
#  'confirmed_cases_processed_filtered.csv',
#  'asia_partially_vaccinated_processed_filtered.csv',
#  'asia_confirmed_cases_processed_filtered.csv',
#  'fully_vaccinated_processed_filtered.csv',
#  'confirmed_deaths_processed_filtered.csv',
#  'asia_fully_vaccinated_processed_filtered.csv',
#  'asia_confirmed_deaths_processed_filtered.csv',
#  'africa_confirmed_deaths_processed_filtered.csv',
#  'africa_confirmed_cases_processed_filtered.csv',
#  'partially_vaccinated_processed_filtered.csv',
#  'africa_partially_vaccinated_processed_filtered.csv',
#  'africa_fully_vaccinated_processed_filtered.csv',
#  'europe_confirmed_deaths_processed_filtered.csv',
#  'europe_partially_vaccinated_processed_filtered.csv',
#  'europe_confirmed_cases_processed_filtered.csv',
# ...

# %%
# Inputs
confirmed_cases_df = pd.read_csv(confirmed_cases_processed_csv, index_col='Country/Region')
fully_vaccinated_df = pd.read_csv(fully_vaccinated_processed_csv, index_col='Country/Region')
partially_vaccinated_df = pd.read_csv(partially_vaccinated_processed_csv, index_col='Country/Region')

# Labels
confirmed_deaths_df = pd.read_csv(confirmed_deaths_processed_csv, index_col='Country/Region')

# %%
confirmed_cases_df
# Out:
#                  1/23/20  1/24/20   1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                               ...
# Afghanistan     0.000000  0.00000  0.000000  ...  0.201893  0.190859  0.175697
# Albania         0.000000  0.00000  0.000000  ...  0.140374  0.160903  0.195346
# Algeria         0.000000  0.00000  0.000000  ...  0.758064  0.726526  0.701847
# Andorra         0.000000  0.00000  0.000000  ...  0.161752  0.159956  0.156862
# Angola          0.000000  0.00000  0.000000  ...  0.399049  0.435356  0.451454
# ...                  ...      ...       ...  ...       ...       ...       ...
# Venezuela       0.000000  0.00000  0.000000  ...  0.530168  0.684505  0.672745
# Vietnam         0.000232  0.00019  0.000155  ...  0.989568  0.915578  0.942631
# Yemen           0.000000  0.00000  0.000000  ...  0.134419  0.143351  0.155665
# Zambia          0.000000  0.00000  0.000000  ...  0.195304  0.188771  0.161016
# ...

# %%
fully_vaccinated_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.005896  0.005896  0.005896
# Albania             0.0      0.0      0.0  ...  0.191388  0.192384  0.193131
# Algeria             0.0      0.0      0.0  ...  0.016858  0.016935  0.016992
# Andorra             0.0      0.0      0.0  ...  0.440114  0.440155  0.440185
# Angola              0.0      0.0      0.0  ...  0.023096  0.023186  0.023253
# ...                 ...      ...      ...  ...       ...       ...       ...
# Uzbekistan          0.0      0.0      0.0  ...  0.037281  0.037497  0.037658
# Venezuela           0.0      0.0      0.0  ...  0.038096  0.038098  0.038099
# Vietnam             0.0      0.0      0.0  ...  0.009901  0.010285  0.010832
# Zambia              0.0      0.0      0.0  ...  0.010886  0.011132  0.011389
# Zimbabwe            0.0      0.0      0.0  ...  0.066389  0.069395  0.072481
#
# ...

# %%
partially_vaccinated_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.020692  0.020700  0.020705
# Albania             0.0      0.0      0.0  ...  0.244367  0.246093  0.247387
# Algeria             0.0      0.0      0.0  ...  0.080630  0.080727  0.080800
# Andorra             0.0      0.0      0.0  ...  0.628968  0.629003  0.629029
# Angola              0.0      0.0      0.0  ...  0.031510  0.031528  0.031541
# ...                 ...      ...      ...  ...       ...       ...       ...
# Uzbekistan          0.0      0.0      0.0  ...  0.191506  0.197058  0.201222
# Venezuela           0.0      0.0      0.0  ...  0.100445  0.100446  0.100447
# Vietnam             0.0      0.0      0.0  ...  0.091787  0.097640  0.104799
# Zambia              0.0      0.0      0.0  ...  0.017300  0.017420  0.017495
# Zimbabwe            0.0      0.0      0.0  ...  0.125552  0.128209  0.131011
#
# ...

# %%
confirmed_deaths_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.136623  0.121222  0.110508
# Albania             0.0      0.0      0.0  ...  0.002596  0.002124  0.003419
# Algeria             0.0      0.0      0.0  ...  0.238910  0.246682  0.245547
# Andorra             0.0      0.0      0.0  ...  0.014752  0.012069  0.009875
# Angola              0.0      0.0      0.0  ...  0.162016  0.175856  0.218105
# ...                 ...      ...      ...  ...       ...       ...       ...
# Venezuela           0.0      0.0      0.0  ...  0.085424  0.109367  0.111130
# Vietnam             0.0      0.0      0.0  ...  0.337436  0.344807  0.340087
# Yemen               0.0      0.0      0.0  ...  0.134763  0.160319  0.164542
# Zambia              0.0      0.0      0.0  ...  0.042944  0.037167  0.032440
# Zimbabwe            0.0      0.0      0.0  ...  0.188018  0.198927  0.183695
#
# ...

# %%
countries_in_confirmed_cases_df =  list(confirmed_cases_df.index)
countries_in_fully_vaccinated_df = list(fully_vaccinated_df.index)
countries_in_partially_vaccinated_df = list(partially_vaccinated_df.index)
countries_in_confirmed_deaths_df = list(confirmed_deaths_df.index)

print('countries_in_confirmed_cases_df =', len(countries_in_confirmed_cases_df),
      '\ncountries_in_fully_vaccinated_df = ', len(countries_in_fully_vaccinated_df),
      '\ncountries_in_partially_vaccinated_df = ', len(countries_in_partially_vaccinated_df),
      '\ncountries_in_confirmed_deaths_df = ', len(countries_in_confirmed_deaths_df))
# Out:
# countries_in_confirmed_cases_df = 189
# countries_in_fully_vaccinated_df =  163
# countries_in_partially_vaccinated_df =  163
# countries_in_confirmed_deaths_df =  189

# %%
# Check if countries in confirmed cases and deaths are the same.
assert(countries_in_confirmed_cases_df == countries_in_confirmed_deaths_df)
# Check if countries in fully and partially vaccinated are the same.
assert(countries_in_fully_vaccinated_df == countries_in_partially_vaccinated_df)

# %%
countries_in_4_datasets = set(countries_in_confirmed_cases_df).intersection(set(countries_in_fully_vaccinated_df))
print(countries_in_4_datasets)
# Out:
# {'Jamaica', 'Netherlands', 'Thailand', 'Namibia', 'Egypt', 'El Salvador', 'Nicaragua', 'Switzerland', 'Botswana', 'Mauritius', 'Vietnam', 'Italy', 'Colombia', 'Ireland', 'Sierra Leone', 'Norway', 'Angola', 'Sri Lanka', 'North Macedonia', 'Guatemala', 'Latvia', 'Sudan', 'Solomon Islands', 'Eswatini', 'Bolivia', 'Denmark', 'Maldives', 'Sao Tome and Principe', 'Senegal', 'Armenia', 'Marshall Islands', 'Ecuador', 'Jordan', 'Pakistan', 'Zambia', 'Nepal', 'Syria', 'Ukraine', 'Dominica', 'Ghana', 'Hungary', 'Malaysia', 'South Sudan', 'Rwanda', 'Kosovo', 'Slovenia', 'Dominican Republic', 'Moldova', 'Saint Kitts and Nevis', 'Poland', 'Bahamas', 'Panama', 'Burma', 'Togo', 'Malawi', 'Japan', 'Gabon', 'Greece', 'Honduras', 'Belize', 'Oman', 'Saint Lucia', 'Turkey', 'Kuwait', 'South Africa', 'Croatia', 'Papua New Guinea', 'Russia', 'Slovakia', 'Guyana', 'Cameroon', 'Singapore', 'Bangladesh', 'Fiji', 'Australia', 'Lebanon', 'Israel', 'India', 'Saint Vincent and the Grenadines', 'Algeria', 'Saudi A
# ...

# %%
confirmed_cases_df = confirmed_cases_df.loc[confirmed_cases_df.index.isin(list(countries_in_4_datasets))]
confirmed_deaths_df = confirmed_deaths_df.loc[confirmed_deaths_df.index.isin(list(countries_in_4_datasets))]
fully_vaccinated_df = fully_vaccinated_df.loc[fully_vaccinated_df.index.isin(list(countries_in_4_datasets))]
partially_vaccinated_df = partially_vaccinated_df.loc[partially_vaccinated_df.index.isin(list(countries_in_4_datasets))]

# %%
confirmed_cases_df
# Out:
#                  1/23/20  1/24/20   1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                               ...
# Afghanistan     0.000000  0.00000  0.000000  ...  0.201893  0.190859  0.175697
# Albania         0.000000  0.00000  0.000000  ...  0.140374  0.160903  0.195346
# Algeria         0.000000  0.00000  0.000000  ...  0.758064  0.726526  0.701847
# Andorra         0.000000  0.00000  0.000000  ...  0.161752  0.159956  0.156862
# Angola          0.000000  0.00000  0.000000  ...  0.399049  0.435356  0.451454
# ...                  ...      ...       ...  ...       ...       ...       ...
# Uzbekistan      0.000000  0.00000  0.000000  ...  0.983029  0.989826  1.000000
# Venezuela       0.000000  0.00000  0.000000  ...  0.530168  0.684505  0.672745
# Vietnam         0.000232  0.00019  0.000155  ...  0.989568  0.915578  0.942631
# Zambia          0.000000  0.00000  0.000000  ...  0.195304  0.188771  0.161016
# ...

# %%
fully_vaccinated_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.005896  0.005896  0.005896
# Albania             0.0      0.0      0.0  ...  0.191388  0.192384  0.193131
# Algeria             0.0      0.0      0.0  ...  0.016858  0.016935  0.016992
# Andorra             0.0      0.0      0.0  ...  0.440114  0.440155  0.440185
# Angola              0.0      0.0      0.0  ...  0.023096  0.023186  0.023253
# ...                 ...      ...      ...  ...       ...       ...       ...
# Uzbekistan          0.0      0.0      0.0  ...  0.037281  0.037497  0.037658
# Venezuela           0.0      0.0      0.0  ...  0.038096  0.038098  0.038099
# Vietnam             0.0      0.0      0.0  ...  0.009901  0.010285  0.010832
# Zambia              0.0      0.0      0.0  ...  0.010886  0.011132  0.011389
# Zimbabwe            0.0      0.0      0.0  ...  0.066389  0.069395  0.072481
#
# ...

# %%
partially_vaccinated_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.020692  0.020700  0.020705
# Albania             0.0      0.0      0.0  ...  0.244367  0.246093  0.247387
# Algeria             0.0      0.0      0.0  ...  0.080630  0.080727  0.080800
# Andorra             0.0      0.0      0.0  ...  0.628968  0.629003  0.629029
# Angola              0.0      0.0      0.0  ...  0.031510  0.031528  0.031541
# ...                 ...      ...      ...  ...       ...       ...       ...
# Uzbekistan          0.0      0.0      0.0  ...  0.191506  0.197058  0.201222
# Venezuela           0.0      0.0      0.0  ...  0.100445  0.100446  0.100447
# Vietnam             0.0      0.0      0.0  ...  0.091787  0.097640  0.104799
# Zambia              0.0      0.0      0.0  ...  0.017300  0.017420  0.017495
# Zimbabwe            0.0      0.0      0.0  ...  0.125552  0.128209  0.131011
#
# ...

# %%
confirmed_deaths_df
# Out:
#                 1/23/20  1/24/20  1/25/20  ...   8/11/21   8/12/21   8/13/21
# Country/Region                             ...
# Afghanistan         0.0      0.0      0.0  ...  0.136623  0.121222  0.110508
# Albania             0.0      0.0      0.0  ...  0.002596  0.002124  0.003419
# Algeria             0.0      0.0      0.0  ...  0.238910  0.246682  0.245547
# Andorra             0.0      0.0      0.0  ...  0.014752  0.012069  0.009875
# Angola              0.0      0.0      0.0  ...  0.162016  0.175856  0.218105
# ...                 ...      ...      ...  ...       ...       ...       ...
# Uzbekistan          0.0      0.0      0.0  ...  0.073393  0.076095  0.078305
# Venezuela           0.0      0.0      0.0  ...  0.085424  0.109367  0.111130
# Vietnam             0.0      0.0      0.0  ...  0.337436  0.344807  0.340087
# Zambia              0.0      0.0      0.0  ...  0.042944  0.037167  0.032440
# Zimbabwe            0.0      0.0      0.0  ...  0.188018  0.198927  0.183695
#
# ...

# %% [markdown]
# ## Let's concatenate the data

# %%
all_data = pd.concat((confirmed_cases_df, confirmed_deaths_df, fully_vaccinated_df, partially_vaccinated_df), axis=0, keys=['cases', 'deaths', 'fully vacc.', 'partially vacc.'])

# %%
all_data
# Out:
#                                 1/23/20  1/24/20  ...   8/12/21   8/13/21
#                 Country/Region                    ...
# cases           Afghanistan         0.0      0.0  ...  0.190859  0.175697
#                 Albania             0.0      0.0  ...  0.160903  0.195346
#                 Algeria             0.0      0.0  ...  0.726526  0.701847
#                 Andorra             0.0      0.0  ...  0.159956  0.156862
#                 Angola              0.0      0.0  ...  0.435356  0.451454
# ...                                 ...      ...  ...       ...       ...
# partially vacc. Uzbekistan          0.0      0.0  ...  0.197058  0.201222
#                 Venezuela           0.0      0.0  ...  0.100446  0.100447
#                 Vietnam             0.0      0.0  ...  0.097640  0.104799
#                 Zambia              0.0      0.0  ...  0.017420  0.017495
#                 Zimbabwe            0.0      0.0  ...  0.128209  0.131011
#
# [648 rows x 569 columns]

# %%
all_data.index.rename(['Type', 'Country/Region'], inplace=True)

# %%
all_data
# Out:
#                                 1/23/20  1/24/20  ...   8/12/21   8/13/21
# Type            Country/Region                    ...
# cases           Afghanistan         0.0      0.0  ...  0.190859  0.175697
#                 Albania             0.0      0.0  ...  0.160903  0.195346
#                 Algeria             0.0      0.0  ...  0.726526  0.701847
#                 Andorra             0.0      0.0  ...  0.159956  0.156862
#                 Angola              0.0      0.0  ...  0.435356  0.451454
# ...                                 ...      ...  ...       ...       ...
# partially vacc. Uzbekistan          0.0      0.0  ...  0.197058  0.201222
#                 Venezuela           0.0      0.0  ...  0.100446  0.100447
#                 Vietnam             0.0      0.0  ...  0.097640  0.104799
#                 Zambia              0.0      0.0  ...  0.017420  0.017495
#                 Zimbabwe            0.0      0.0  ...  0.128209  0.131011
#
# [648 rows x 569 columns]

# %%
all_data = all_data.reorder_levels([1, 0]).sort_values(by=['Country/Region', 'Type'])

# %%
all_data.iloc[:, -20:]
# Out:
#                                  7/25/21   7/26/21  ...   8/12/21   8/13/21
# Country/Region Type                                 ...
# Afghanistan    cases            0.281133  0.309873  ...  0.190859  0.175697
#                deaths           0.188531  0.267522  ...  0.121222  0.110508
#                fully vacc.      0.005882  0.005885  ...  0.005896  0.005896
#                partially vacc.  0.021979  0.022277  ...  0.020700  0.020705
# Albania        cases            0.021725  0.020464  ...  0.160903  0.195346
# ...                                  ...       ...  ...       ...       ...
# Zambia         partially vacc.  0.013894  0.014257  ...  0.017420  0.017495
# Zimbabwe       cases            0.813507  0.830674  ...  0.356581  0.352464
#                deaths           0.287404  0.298764  ...  0.198927  0.183695
#                fully vacc.      0.045276  0.045732  ...  0.069395  0.072481
#                partially vacc.  0.087574  0.090740  ...  0.128209  0.131011
#
# ...

# %%
population_data = {'Afghanistan': 37172386, 'Albania': 2866376, 'Algeria': 42228429, 'American Samoa': 55465, 'Andorra': 77006, 'Angola': 30809762, 'Anguilla': 15094, 'Antarctica': 1106, 'Antigua and Barbuda': 96286, 'Argentina': 44494502, 'Armenia': 2951776, 'Aruba': 105845, 'Australia': 24982688, 'Austria': 8840521, 'Azerbaijan': 9939800, 'Bahamas': 385640, 'Bahrain': 1569439, 'Bangladesh': 161356039, 'Barbados': 286641, 'Belarus': 9483499, 'Belgium': 11433256, 'Belize': 383071, 'Benin': 11485048, 'Bermuda': 63973, 'Bhutan': 754394, 'Bolivia': 11353142, 'Bosnia and Herzegovina': 3323929, 'Botswana': 2254126, 'Bouvet Island': 0, 'Brazil': 209469333, 'British Indian Ocean Territory': 0, 'Brunei': 428962, 'Bulgaria': 7025037, 'Burkina Faso': 19751535, 'Burundi': 11175378, 'Cambodia': 16249798, 'Cameroon': 25216237, 'Canada': 37057765, 'Cabo Verde': 543767, 'Cayman Islands': 64174, 'Central African Republic': 4666377, 'Chad': 15477751, 'Chile': 18729160, 'China': 1392730000, 'Christmas Island': 1402, 'Cocos (Keeling) Islands': 596, 'Colombia': 49648685, 'Comoros': 832322, 'Congo (Brazzaville)': 5244363, 'Cook Islands': 17379, 'Costa Rica': 4999441, 'Croatia': 4087843, 'Cuba': 11338138, 'Cyprus': 1189265, 'Czechia': 10629928, 'Denmark': 5793636, 'Djibouti': 958920, 'Dominica': 71625, 'Dominican Republic': 10627165, 'Timor-Leste': 1267972, 'Ecuador': 17084357, 'Egypt': 98423595, 'El Salvador': 6420744, 'England': 55619400, 'Equatorial Guinea': 1308974, 'Eritrea': 6213972, 'Estonia': 1321977, 'Ethiopia': 109224559, 'Falkland Islands': 2840, 'Faroe Islands': 48497, 'Fiji': 883483, 'Finland': 5515525, 'France': 66977107, 'French Guiana': 290691, 'French Polynesia': 277679, 'French Southern territories': 0, 'Gabon': 2119275, 'Gambia': 2280102, 'Georgia': 3726549, 'Germany': 82905782, 'Ghana': 29767108, 'Gibraltar': 33718, 'Greece': 10731726, 'Greenland': 56025, 'Grenada': 111454, 'Guadeloupe': 395700, 'Guam': 165768, 'Guatemala': 17247807, 'Guinea': 12414318, 'Guinea-Bissau': 1874309, 'Guyana': 779004, 'Haiti': 11123176, 'Heard Island and McDonald Islands': 0, 'Holy See (Vatican City State)': 825, 'Honduras': 9587522, 'Hong Kong': 7451000, 'Hungary': 9775564, 'Iceland': 352721, 'India': 1352617328, 'Indonesia': 267663435, 'Iran': 81800269, 'Iraq': 38433600, 'Ireland': 4867309, 'Israel': 8882800, 'Italy': 60421760, "Cote d'Ivoire": 25069229, 'Jamaica': 2934855, 'Japan': 126529100, 'Jordan': 9956011, 'Kazakhstan': 18272430, 'Kenya': 51393010, 'Kiribati': 115847, 'Kosovo': 1935259,  'Kuwait': 4137309, 'Kyrgyzstan': 6322800, 'Laos': 7061507, 'Latvia': 1927174, 'Lebanon': 6848925, 'Lesotho': 2108132, 'Liberia': 4818977, 'Libya': 6678567, 'Liechtenstein': 37910, 'Lithuania': 2801543, 'Luxembourg': 607950, 'Macao': 631636, 'Madagascar': 26262368, 'Malawi': 18143315, 'Malaysia': 31528585, 'Maldives': 515696, 'Mali': 19077690, 'Malta': 484630, 'Marshall Islands': 58413, 'Martinique': 376480, 'Mauritania': 4403319, 'Mauritius': 1265303, 'Mayotte': 270372, 'Mexico': 126190788, 'Micronesia': 112640, 'Moldova': 2706049, 'Monaco': 38682, 'Mongolia': 3170208, 'Montenegro': 631219, 'Montserrat': 5900, 'Morocco': 36029138, 'Mozambique': 29495962, 'Burma': 53708395, 'Namibia': 2448255, 'Nauru': 12704, 'Nepal': 28087871, 'Netherlands': 17231624, 'Netherlands Antilles': 227049, 'New Caledonia': 284060, 'New Zealand': 4841000, 'Nicaragua': 6465513, 'Niger': 22442948, 'Nigeria': 195874740, 'Niue': 1624, 'Norfolk Island': 2169, 'North Korea': 25549819, 'North Macedonia': 2084367, 'Northern Ireland': 1885400, 'Northern Mariana Islands': 56882, 'Norway': 5311916, 'Oman': 4829483, 'Pakistan': 212215030, 'Palau': 17907, 'Palestine': 4569087, 'Panama': 4176873, 'Papua New Guinea': 8606316, 'Paraguay': 6956071, 'Peru': 31989256, 'Philippines': 106651922, 'Pitcairn': 67, 'Poland': 37974750, 'Portugal': 10283822, 'Puerto Rico': 3195153, 'Qatar': 2781677, 'Reunion': 859959, 'Romania': 19466145, 'Russia': 144478050, 'Rwanda': 12301939, 'Saint Helena': 6600, 'Saint Kitts and Nevis': 52441, 'Saint Lucia': 181889, 'Saint Pierre and Miquelon': 5888, 'Saint Vincent and the Grenadines': 110210, 'Samoa': 196130, 'San Marino': 33785, 'Sao Tome and Principe': 211028, 'Saudi Arabia': 33699947, 'Scotland': 5424800, 'Senegal': 15854360, 'Serbia': 6963764, 'Seychelles': 96762, 'Sierra Leone': 7650154, 'Singapore': 5638676, 'Slovakia': 5446771, 'Slovenia': 2073894, 'Solomon Islands': 652858, 'Somalia': 15008154, 'South Africa': 57779622, 'South Georgia and the South Sandwich Islands': 30, 'Korea, South': 51606633, 'South Sudan': 10975920, 'Spain': 46796540, 'Sri Lanka': 21670000, 'Sudan': 41801533, 'Suriname': 575991, 'Svalbard and Jan Mayen': 2572, 'Eswatini': 1136191, 'Sweden': 10175214, 'Switzerland': 8513227, 'Syria': 16906283, 'Taiwan*': 23568378, 'Tajikistan': 9100837, 'Tanzania': 56318348, 'Thailand': 69428524, 'Congo (Kinshasa)': 84068091, 'Togo': 7889094, 'Tokelau': 1411, 'Tonga': 103197, 'Trinidad and Tobago': 1389858, 'Tunisia': 11565204, 'Turkey': 82319724, 'Turkmenistan': 5850908, 'Turks and Caicos Islands': 37665, 'Tuvalu': 11508, 'Uganda': 42723139, 'Ukraine': 44622516, 'United Arab Emirates': 9630959, 'United Kingdom': 66460344, 'US': 326687501, 'United States Minor Outlying Islands': 300, 'Uruguay': 3449299, 'Uzbekistan': 32955400, 'Vanuatu': 292680, 'Venezuela': 28870195, 'Vietnam': 95540395, 'Virgin Islands, British': 29802, 'Virgin Islands, U.S.': 106977, 'Wales': 3139000, 'Wallis and Futuna': 15289, 'Western Sahara': 652271, 'Yemen': 28498687, 'Zambia': 17351822, 'Zimbabwe': 14439018}

def graph_countries(countries_name):
    for country_name in set(countries_name):
        title = country_name + ' ' + str(population_data[country_name])
        all_data.loc[country_name].loc[['cases', 'deaths']].T.plot(figsize=(20, 4), title=title)
        all_data.loc[country_name].loc[['fully vacc.', 'partially vacc.']].T.plot(figsize=(20, 4))

# %% [markdown]
# ## Spliting up by regions

# %%
country_to_region = {'Afghanistan': 'Asia', 'Albania': 'Europe', 'Algeria': 'Africa', 'Andorra': 'Europe', 'Angola': 'Africa', 'Antigua and Barbuda': 'North America', 'Argentina': 'South America', 'Armenia': 'Asia', 'Australia': 'Oceania', 'Austria': 'Europe', 'Azerbaijan': 'Asia', 'Bahamas': 'North America', 'Bahrain': 'Asia', 'Bangladesh': 'Asia', 'Barbados': 'North America', 'Belarus': 'Europe', 'Belgium': 'Europe', 'Belize': 'North America', 'Bhutan': 'Asia', 'Bolivia': 'South America', 'Bosnia and Herzegovina': 'Europe', 'Botswana': 'Africa', 'Brazil': 'South America', 'Brunei': 'Asia', 'Bulgaria': 'Europe', 'Cambodia': 'Asia', 'Cameroon': 'Africa', 'Canada': 'North America', 'Chile': 'South America', 'China': 'Asia', 'Colombia': 'South America', 'Costa Rica': 'North America', 'Croatia': 'Europe', 'Cyprus': 'Asia', 'Czechia': 'Europe', 'Denmark': 'Europe', 'Dominica': 'North America', 'Dominican Republic': 'North America', 'Ecuador': 'South America', 'Egypt': 'Africa', 'El Salvador': 'North America', 'Equatorial Guinea': 'Africa', 'Estonia': 'Europe', 'Ethiopia': 'Africa', 'Fiji': 'Oceania', 'Finland': 'Europe', 'France': 'Europe', 'Gabon': 'Africa', 'Gambia': 'Africa', 'Georgia': 'Asia', 'Germany': 'Europe', 'Ghana': 'Africa', 'Greece': 'Europe', 'Grenada': 'North America', 'Guatemala': 'North America', 'Guinea': 'Africa', 'Guyana': 'South America', 'Honduras': 'North America', 'Hungary': 'Europe', 'Iceland': 'Europe', 'India': 'Asia', 'Indonesia': 'Asia', 'Iran': 'Asia', 'Iraq': 'Asia', 'Ireland': 'Europe', 'Israel': 'Asia', 'Italy': 'Europe', "Cote d'Ivoire": 'Africa', 'Jamaica': 'North America', 'Japan': 'Asia', 'Jordan': 'Asia', 'Kazakhstan': 'Asia', 'Kenya': 'Africa', 'Kuwait': 'Asia', 'Kyrgyzstan': 'Asia', 'Laos': 'Asia', 'Latvia': 'Europe', 'Lebanon': 'Asia', 'Liechtenstein': 'Europe', 'Lithuania': 'Europe', 'Luxembourg': 'Europe', 'North Macedonia': 'Europe', 'Malawi': 'Africa', 'Malaysia': 'Asia', 'Maldives': 'Asia', 'Mali': 'Africa', 'Malta': 'Europe', 'Marshall Islands': 'Oceania', 'Mauritania': 'Africa', 'Mauritius': 'Africa', 'Mexico': 'North America', 'Micronesia': 'Oceania', 'Moldova': 'Europe', 'Monaco': 'Europe', 'Mongolia': 'Asia', 'Montenegro': 'Europe', 'Morocco': 'Africa', 'Mozambique': 'Africa', 'Burma': 'Asia', 'Namibia': 'Africa', 'Nepal': 'Asia', 'Netherlands': 'Europe', 'New Zealand': 'Oceania', 'Nicaragua': 'North America', 'Nigeria': 'Africa', 'Norway': 'Europe', 'Oman': 'Asia', 'Pakistan': 'Asia', 'Panama': 'North America', 'Papua New Guinea': 'Oceania', 'Paraguay': 'South America', 'Peru': 'South America', 'Philippines': 'Asia', 'Poland': 'Europe', 'Portugal': 'Europe', 'Qatar': 'Asia', 'Romania': 'Europe', 'Russia': 'Europe', 'Rwanda': 'Africa', 'Saint Kitts and Nevis': 'North America', 'Saint Lucia': 'North America', 'Saint Vincent and the Grenadines': 'North America', 'San Marino': 'Europe', 'Sao Tome and Principe': 'Africa', 'Saudi Arabia': 'Asia', 'Senegal': 'Africa', 'Serbia': 'Europe', 'Seychelles': 'Africa', 'Sierra Leone': 'Africa', 'Singapore': 'Asia', 'Slovakia': 'Europe', 'Slovenia': 'Europe', 'Solomon Islands': 'Oceania', 'South Africa': 'Africa', 'Kosovo': 'Europe', 'Korea, South': 'Asia', 'South Sudan': 'Africa', 'Spain': 'Europe', 'Sri Lanka': 'Asia', 'Sudan': 'Africa', 'Suriname': 'South America', 'Eswatini': 'Africa', 'Sweden': 'Europe', 'Switzerland': 'Europe', 'Syria': 'Asia', 'Thailand': 'Asia', 'Togo': 'Africa', 'Trinidad and Tobago': 'North America', 'Tunisia': 'Africa', 'Turkey': 'Asia', 'Uganda': 'Africa', 'Ukraine': 'Europe', 'United Arab Emirates': 'Asia', 'United Kingdom': 'Europe', 'US': 'North America', 'Uruguay': 'South America', 'Uzbekistan': 'Asia', 'Venezuela': 'South America', 'Vietnam': 'Asia', 'Taiwan*': 'Asia', 'Zambia': 'Africa', 'Zimbabwe': 'Africa'}
region_countries = {'Asia': ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Burma', 'Nepal', 'Oman', 'Pakistan', 'Philippines', 'Qatar', 'Saudi Arabia', 'Singapore', 'Korea, South', 'Sri Lanka', 'Syria', 'Thailand', 'Turkey', 'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Taiwan*'], 'Europe': ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'North Macedonia', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Kosovo', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom'], 'Africa': ['Algeria', 'Angola', 'Botswana', 'Cameroon', 'Egypt', 'Equatorial Guinea', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guinea', "Cote d'Ivoire", 'Kenya', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'South Africa', 'South Sudan', 'Sudan', 'Eswatini', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'], 'North America': ['Antigua and Barbuda', 'Bahamas', 'Barbados', 'Belize', 'Canada', 'Costa Rica', 'Dominica', 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua', 'Panama', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Trinidad and Tobago', 'US'], 'South America': ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'], 'Oceania': ['Australia', 'Fiji', 'Marshall Islands', 'Micronesia', 'New Zealand', 'Papua New Guinea', 'Solomon Islands']}

# %% [markdown]
# ### Asia

# %%
region = 'Asia'
asia_countries = region_countries[region]

asia_data = all_data.loc[asia_countries, :]
asia_data_countries = list(set(asia_data.index.get_level_values(0)))
asia_data_countries.sort()

asia_confirmed_cases_df = confirmed_cases_df.loc[asia_countries, :]
asia_confirmed_deaths_df = confirmed_deaths_df.loc[asia_countries, :]
asia_partially_vaccinated_df = partially_vaccinated_df.loc[asia_countries, :]
asia_fully_vaccinated_df = fully_vaccinated_df.loc[asia_countries, :]

# %%
assert(asia_data_countries == sorted(asia_confirmed_cases_df.index.to_list()))

# %%
graph_countries(asia_countries)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Africa

# %%
region = 'Africa'
africa_countries = region_countries[region]

africa_data = all_data.loc[africa_countries, :]
africa_data_countries = list(set(africa_data.index.get_level_values(0)))
africa_data_countries.sort()

africa_confirmed_cases_df = confirmed_cases_df.loc[africa_countries, :]
africa_confirmed_deaths_df = confirmed_deaths_df.loc[africa_countries, :]
africa_partially_vaccinated_df = partially_vaccinated_df.loc[africa_countries, :]
africa_fully_vaccinated_df = fully_vaccinated_df.loc[africa_countries, :]

# %%
assert(africa_data_countries == sorted(africa_confirmed_cases_df.index.to_list()))

# %%
graph_countries(africa_countries)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Europe

# %%
region = 'Europe'
europe_countries = region_countries[region]

europe_data = all_data.loc[europe_countries, :]
europe_data_countries = list(set(europe_data.index.get_level_values(0)))
europe_data_countries.sort()

europe_confirmed_cases_df = confirmed_cases_df.loc[europe_countries, :]
europe_confirmed_deaths_df = confirmed_deaths_df.loc[europe_countries, :]
europe_partially_vaccinated_df = partially_vaccinated_df.loc[europe_countries, :]
europe_fully_vaccinated_df = fully_vaccinated_df.loc[europe_countries, :]

# %%
assert(europe_data_countries == sorted(europe_confirmed_cases_df.index.to_list()))

# %%
graph_countries(europe_countries)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### North America

# %%
region = 'North America'
north_america_countries = region_countries[region]

north_america_data = all_data.loc[north_america_countries, :]
north_america_data_countries = list(set(north_america_data.index.get_level_values(0)))
north_america_data_countries.sort()

north_america_confirmed_cases_df = confirmed_cases_df.loc[north_america_countries, :]
north_america_confirmed_deaths_df = confirmed_deaths_df.loc[north_america_countries, :]
north_america_partially_vaccinated_df = partially_vaccinated_df.loc[north_america_countries, :]
north_america_fully_vaccinated_df = fully_vaccinated_df.loc[north_america_countries, :]

# %%
assert(north_america_data_countries == sorted(north_america_confirmed_cases_df.index.to_list()))

# %%
graph_countries(north_america_countries)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %% [markdown]
# ### Oceania

# %%
region = 'Oceania'
oceania_countries = region_countries[region]

oceania_data = all_data.loc[oceania_countries, :]
oceania_data_countries = list(set(oceania_data.index.get_level_values(0)))
oceania_data_countries.sort()

oceania_confirmed_cases_df = confirmed_cases_df.loc[oceania_countries, :]
oceania_confirmed_deaths_df = confirmed_deaths_df.loc[oceania_countries, :]
oceania_partially_vaccinated_df = partially_vaccinated_df.loc[oceania_countries, :]
oceania_fully_vaccinated_df = fully_vaccinated_df.loc[oceania_countries, :]

# %%
assert(oceania_data_countries == sorted(oceania_confirmed_cases_df.index.to_list()))

# %%
graph_countries(oceania_countries)

# %% [markdown]
# ### South America

# %%
region = 'South America'
south_america_countries = region_countries[region]

south_america_data = all_data.loc[south_america_countries, :]
south_america_data_countries = list(set(south_america_data.index.get_level_values(0)))
south_america_data_countries.sort()

south_america_confirmed_cases_df = confirmed_cases_df.loc[south_america_countries, :]
south_america_confirmed_deaths_df = confirmed_deaths_df.loc[south_america_countries, :]
south_america_partially_vaccinated_df = partially_vaccinated_df.loc[south_america_countries, :]
south_america_fully_vaccinated_df = fully_vaccinated_df.loc[south_america_countries, :]

# %%
assert(south_america_data_countries == sorted(south_america_confirmed_cases_df.index.to_list()))

# %%
graph_countries(south_america_countries)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...

# %% [markdown]
# ### South and central America

# %%
region1 = 'South America'
region2 = 'North America'

south_america_countries = region_countries[region1]
north_america_countries = region_countries[region2]

south_and_central_america_countries = south_america_countries + north_america_countries
# Delete Canada and USA.
south_and_central_america_countries.remove('US')
south_and_central_america_countries.remove('Canada')
south_and_central_america_countries.remove('Ecuador') # Presents so many outliers. It cannot be appropriately cleaned.

south_and_central_america_data = all_data.loc[south_and_central_america_countries, :]
south_and_central_america_data_countries = list(set(south_and_central_america_data.index.get_level_values(0)))
south_and_central_america_data_countries.sort()

south_and_central_america_confirmed_cases_df = confirmed_cases_df.loc[south_and_central_america_countries, :]
south_and_central_america_confirmed_deaths_df = confirmed_deaths_df.loc[south_and_central_america_countries, :]
south_and_central_america_partially_vaccinated_df = partially_vaccinated_df.loc[south_and_central_america_countries, :]
south_and_central_america_fully_vaccinated_df = fully_vaccinated_df.loc[south_and_central_america_countries, :]

# %%
graph_countries(south_and_central_america_countries)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### All countries

# %%
region = 'All countries'

all_countries_confirmed_cases_df = confirmed_cases_df
all_countries_confirmed_deaths_df = confirmed_deaths_df
all_countries_partially_vaccinated_df = partially_vaccinated_df
all_countries_fully_vaccinated_df = fully_vaccinated_df

# %% [markdown]
# ## Saving data

# %%
confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/confirmed_cases_processed_filtered.csv')
confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/confirmed_deaths_processed_filtered.csv')

partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/partially_vaccinated_processed_filtered.csv')
fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/fully_vaccinated_processed_filtered.csv')

# %%
asia_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/asia_confirmed_cases_processed_filtered.csv')
asia_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/asia_confirmed_deaths_processed_filtered.csv')

asia_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/asia_partially_vaccinated_processed_filtered.csv')
asia_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/asia_fully_vaccinated_processed_filtered.csv')

# %%
africa_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/africa_confirmed_cases_processed_filtered.csv')
africa_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/africa_confirmed_deaths_processed_filtered.csv')

africa_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/africa_partially_vaccinated_processed_filtered.csv')
africa_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/africa_fully_vaccinated_processed_filtered.csv')

# %%
europe_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/europe_confirmed_cases_processed_filtered.csv')
europe_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/europe_confirmed_deaths_processed_filtered.csv')

europe_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/europe_partially_vaccinated_processed_filtered.csv')
europe_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/europe_fully_vaccinated_processed_filtered.csv')

# %%
north_america_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/north_america_confirmed_cases_processed_filtered.csv')
north_america_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/north_america_confirmed_deaths_processed_filtered.csv')

north_america_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/north_america_partially_vaccinated_processed_filtered.csv')
north_america_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/north_america_fully_vaccinated_processed_filtered.csv')

# %%
oceania_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/oceania_confirmed_cases_processed_filtered.csv')
oceania_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/oceania_confirmed_deaths_processed_filtered.csv')

oceania_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/oceania_partially_vaccinated_processed_filtered.csv')
oceania_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/oceania_fully_vaccinated_processed_filtered.csv')

# %%
south_america_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_america_confirmed_cases_processed_filtered.csv')
south_america_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_america_confirmed_deaths_processed_filtered.csv')

south_america_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_america_partially_vaccinated_processed_filtered.csv')
south_america_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_america_fully_vaccinated_processed_filtered.csv')

# %%
south_and_central_america_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_and_central_america_confirmed_cases_processed_filtered.csv')
south_and_central_america_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_and_central_america_confirmed_deaths_processed_filtered.csv')

south_and_central_america_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_and_central_america_partially_vaccinated_processed_filtered.csv')
south_and_central_america_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/south_and_central_america_fully_vaccinated_processed_filtered.csv')

# %%
all_countries_confirmed_cases_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/all_countries_confirmed_cases_processed_filtered.csv')
all_countries_confirmed_deaths_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/all_countries_confirmed_deaths_processed_filtered.csv')

all_countries_partially_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/all_countries_partially_vaccinated_processed_filtered.csv')
all_countries_fully_vaccinated_df.to_csv(r'/content/gdrive/MyDrive/Covid_Project/Data/Processed_Data/all_countries_fully_vaccinated_processed_filtered.csv')

# %%
assert(confirmed_cases_df.loc[confirmed_cases_df.isna().any(axis=1)].empty)
assert(confirmed_deaths_df.loc[confirmed_deaths_df.isna().any(axis=1)].empty)
assert(partially_vaccinated_df.loc[partially_vaccinated_df.isna().any(axis=1)].empty)
assert(fully_vaccinated_df.loc[fully_vaccinated_df.isna().any(axis=1)].empty)
